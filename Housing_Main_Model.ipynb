# %% [markdown]
# ## Housing Main Model

# %% [markdown]
# ## Import Packages and Load dataset

# %%
# Import
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats
from scipy.stats import norm, skew
from sklearn.preprocessing import LabelEncoder
# %matplotlib inline
pd.set_option("display.max_columns", 101)

# %%
# Load train dataset
df_train = pd.read_csv('train.csv')
df_test = pd.read_csv('test.csv')

# %% [markdown]
# ## Overview of Dataset

# %%
# View a Sample
df_train.sample(10)
df_test.sample(10)
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 1104  2565          20       RL        126.0    13108   Pave   NaN      IR2
# 204   1665          20       RL         95.0    11578   Pave   NaN      Reg
# 1326  2787          50       RM         56.0     9576   Pave   NaN      Reg
# 272   1733          20       RL          NaN     9079   Pave   NaN      IR1
# 348   1809          70       RM         90.0     9900   Pave   NaN      Reg
# 848   2309         120       RL         48.0     7841   Pave   NaN      IR1
# 677   2138          85       RL          NaN    11235   Pave   NaN      Reg
# 802   2263          60       RL         98.0    12328   Pave   NaN      IR1
# 74    1535          50       RM         69.0    11851   Pave   NaN      Reg
# 215   1676         120       RL         34.0     5122   Pave   NaN      IR1
#
#      LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 1104         HLS    AllPub    Inside       Gtl      Crawfor       Norm
# 204          Lvl    AllPub    Inside       Gtl      NridgHt       Norm
# 1326         Lvl    AllPub    Inside       Gtl      OldTown       Norm
# 272          Lvl    AllPub    Inside       Gtl       Sawyer       Norm
# 348          Lvl    AllPub    Corner       Gtl      OldTown       Norm
# 848          Lvl    AllPub    Inside       Gtl      NridgHt       Norm
# 677          Lvl    AllPub    Corner       Gtl       Sawyer      Feedr
# 802          Lvl    AllPub    Inside       Gtl      StoneBr       Norm
# 74           Lvl    AllPub    Inside       Gtl      OldTown     Artery
# 215          Lvl    AllPub    Inside       Gtl      NridgHt       Norm
#
#      Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  \
# 1104       Norm     1Fam     1Story            5            5       1951
# 204        Norm     1Fam     1Story            9            5       2008
# 1326       Norm     1Fam     1.5Fin            6            7       1945
# 272        Norm     1Fam     1Story            5            5       1961
# 348        Norm     1Fam     2Story            5            8       1910
# 848        Norm   TwnhsE     1Story            9            5       2005
# 677        Norm     1Fam     SFoyer            5            6       1963
# 802        Norm     1Fam     2Story            8            5       2005
# 74         Norm     1Fam     1.5Fin            5            7       1948
# 215        Norm    Twnhs     1Story            6            5       2005
#
#       YearRemodAdd RoofStyle RoofMatl Exterior1st Exterior2nd MasVnrType  \
# 1104          1951     Gable  CompShg     Wd Sdng     Wd Sdng       None
# 204           2008     Gable  CompShg     VinylSd     VinylSd      Stone
# 1326          1950     Gable  CompShg     VinylSd     VinylSd       None
# 272           1961     Gable  CompShg     Wd Sdng     Plywood       None
# 348           2002     Gable  CompShg     VinylSd     VinylSd       None
# 848           2005       Hip  CompShg     MetalSd     MetalSd    BrkFace
# 677           1963     Gable  CompShg     HdBoard     Wd Sdng       None
# 802           2005       Hip  CompShg     VinylSd     VinylSd      Stone
# 74            2009     Gable  CompShg     VinylSd     VinylSd       None
# 215           2005     Gable  CompShg     VinylSd     VinylSd      Stone
#
#       MasVnrArea ExterQual ExterCond Foundation BsmtQual BsmtCond  \
# 1104         0.0        TA        TA     CBlock      NaN      NaN
# 204        302.0        Ex        TA      PConc       Ex       TA
# 1326         0.0        TA        TA     CBlock       Fa       TA
# 272          0.0        TA        TA     CBlock       TA       TA
# 348          0.0        Gd        TA     CBlock       TA       TA
# 848        394.0        Ex        TA      PConc       Ex       TA
# 677          0.0        TA        TA     CBlock       Gd       TA
# 802        146.0        Gd        TA      PConc       Ex       TA
# 74           0.0        TA        Gd     BrkTil       TA       TA
# 215        135.0        Gd        TA      PConc       Gd       TA
#
#      BsmtExposure BsmtFinType1  BsmtFinSF1 BsmtFinType2  BsmtFinSF2  \
# 1104          NaN          NaN         0.0          NaN         0.0
# 204            No          Unf         0.0          Unf         0.0
# 1326           No          Rec       310.0          Unf         0.0
# 272            No          BLQ       864.0          Unf         0.0
# 348            No          Unf         0.0          Unf         0.0
# 848            No          GLQ       848.0          Unf         0.0
# 677            Av          ALQ       784.0          Unf         0.0
# 802            Mn          GLQ       986.0          Unf         0.0
# 74             No          BLQ       780.0          Unf         0.0
# 215            Av          GLQ       881.0          Unf         0.0
#
#       BsmtUnfSF  TotalBsmtSF Heating HeatingQC CentralAir Electrical  \
# 1104        0.0          0.0    GasA        Fa          Y      SBrkr
# 204      1736.0       1736.0    GasA        Ex          Y      SBrkr
# 1326      460.0        770.0    GasA        TA          Y      SBrkr
# 272         0.0        864.0    GasA        TA          Y      SBrkr
# 348       504.0        504.0    GasA        Ex          Y      SBrkr
# 848       729.0       1577.0    GasA        Ex          Y      SBrkr
# 677       197.0        981.0    GasA        TA          Y      SBrkr
# 802       163.0       1149.0    GasA        Ex          Y      SBrkr
# 74        247.0       1027.0    GasA        Ex          Y      SBrkr
# 215       425.0       1306.0    GasA        Ex          Y      SBrkr
#
#       1stFlrSF  2ndFlrSF  LowQualFinSF  GrLivArea  BsmtFullBath  BsmtHalfBath  \
# 1104      1226         0             0       1226           0.0           0.0
# 204       1736         0             0       1736           0.0           0.0
# 1326       885       297             0       1182           0.0           0.0
# 272        864         0             0        864           0.0           0.0
# 348        764       700             0       1464           0.0           0.0
# 848       1577         0             0       1577           1.0           0.0
# 677       1075         0             0       1075           1.0           0.0
# 802       1164      1377             0       2541           1.0           0.0
# 74        1027       606             0       1633           0.0           0.0
# 215       1306         0             0       1306           1.0           0.0
#
#       FullBath  HalfBath  BedroomAbvGr  KitchenAbvGr KitchenQual  \
# 1104         1         1             2             1          TA
# 204          2         0             3             1          Ex
# 1326         1         1             3             1          TA
# 272          1         0             2             1          TA
# 348          2         0             3             1          TA
# 848          2         0             2             1          Ex
# 677          1         0             3             1          Gd
# 802          3         1             4             1          Ex
# 74           1         0             3             1          Gd
# 215          2         0             1             1          Gd
#
#       TotRmsAbvGrd Functional  Fireplaces FireplaceQu GarageType  GarageYrBlt  \
# 1104             7       Min1           1          Gd     Attchd       1951.0
# 204              7        Typ           1          Gd     Attchd       2008.0
# 1326             5        Typ           0         NaN     Detchd       1945.0
# 272              5        Typ           0         NaN     Attchd       1961.0
# 348              7        Typ           0         NaN        NaN          NaN
# 848              6        Typ           1          Gd     Attchd       2005.0
# 677              6        Typ           0         NaN     Detchd       1996.0
# 802             10        Typ           1          Gd    BuiltIn       2005.0
# 74               7        Typ           1          Gd     Detchd       1948.0
# 215              5        Typ           1          Gd     Attchd       2005.0
#
#      GarageFinish  GarageCars  GarageArea GarageQual GarageCond PavedDrive  \
# 1104          Fin         2.0       400.0         TA         TA          Y
# 204           RFn         3.0       834.0         TA         TA          Y
# 1326          Unf         1.0       378.0         Fa         TA          Y
# 272           Unf         1.0       440.0         TA         TA          Y
# 348           NaN         0.0         0.0        NaN        NaN          N
# 848           RFn         2.0       564.0         TA         TA          Y
# 677           Unf         2.0       440.0         TA         TA          Y
# 802           Fin         3.0       729.0         TA         TA          Y
# 74            Unf         1.0       240.0         TA         TA          Y
# 215           RFn         2.0       624.0         TA         TA          Y
#
#       WoodDeckSF  OpenPorchSF  EnclosedPorch  3SsnPorch  ScreenPorch  \
# 1104         174           24            120          0          228
# 204          319           90              0          0            0
# 1326           0            0              0          0            0
# 272          158            0              0          0            0
# 348            0            0            176          0            0
# 848          203           39              0          0            0
# 677           64            0              0          0           64
# 802          120           32              0          0            0
# 74             0          100            126          0            0
# 215          170           63              0          0            0
#
#       PoolArea PoolQC  Fence MiscFeature  MiscVal  MoSold  YrSold SaleType  \
# 1104         0    NaN    NaN         NaN        0       6    2007       WD
# 204          0    NaN    NaN         NaN        0       7    2009       WD
# 1326         0    NaN   GdWo         NaN        0       5    2006       WD
# 272          0    NaN    NaN         NaN        0       7    2009       WD
# 348          0    NaN    NaN         NaN        0       3    2009       WD
# 848          0    NaN    NaN         NaN        0       5    2007       WD
# 677          0    NaN  MnPrv         NaN        0       5    2008       WD
# 802          0    NaN    NaN         NaN        0       7    2007       WD
# 74           0    NaN    NaN         NaN        0       6    2010       WD
# 215          0    NaN    NaN         NaN        0       3    2009       WD
#
#      SaleCondition
# 1104        Normal
# 204         Normal
# 1326        Normal
# 272         Normal
# 348         Normal
# 848         Normal
# 677        Abnorml
# 802         Normal
# 74          Normal
# 215         Normal

# %%
df_train.shape
df_test.shape
# Out:
# (1459, 80)

# %%
df_train.columns
# Out:
# Index(['Id', 'MSSubClass', 'MSZoning', 'LotFrontage', 'LotArea', 'Street',
#        'Alley', 'LotShape', 'LandContour', 'Utilities', 'LotConfig',
#        'LandSlope', 'Neighborhood', 'Condition1', 'Condition2', 'BldgType',
#        'HouseStyle', 'OverallQual', 'OverallCond', 'YearBuilt', 'YearRemodAdd',
#        'RoofStyle', 'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType',
#        'MasVnrArea', 'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual',
#        'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinSF1',
#        'BsmtFinType2', 'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', 'Heating',
#        'HeatingQC', 'CentralAir', 'Electrical', '1stFlrSF', '2ndFlrSF',
#        'LowQualFinSF', 'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath',
#        'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'KitchenQual',
#        'TotRmsAbvGrd', 'Functional', 'Fireplaces', 'FireplaceQu', 'GarageType',
#        'GarageYrBlt', 'GarageFinish', 'GarageCars', 'GarageArea', 'GarageQual',
#        'GarageCond', 'PavedDrive', 'WoodDeckSF', 'OpenPorchSF',
#        'EnclosedPorch', '3SsnPorch', 'ScreenPorch', 'PoolArea', 'PoolQC',
#        'Fence', 'MiscFeature', 'MiscVal', 'MoSold', 'YrSold', 'SaleType',
#        'SaleCondition', 'SalePrice'],
#       dtype='object')

# %%
# Check for missing values
print('Duplicatedt train values:', df_train.duplicated().sum())
print('Duplicated test values:', df_test.duplicated().sum())
# Out:
# Duplicatedt train values: 0
# Duplicated test values: 0

# %% [markdown]
# ### Merge Datasets for Processing

# %%
# Drop ID Column
df_train = df_train.drop(columns=['Id'])
df_test = df_test.drop(columns=['Id'])

# %%
# Create a set variable to differnetiate between train and test
df_train['section'] = "Train"
df_test['section'] = "Test"

# %%
# Create a Sale Price column for df_test and set to 0 as a placeholder
df_test['SalePrice'] = 0

# %%
# Stack the datasets
df = pd.concat([df_train, df_test], ignore_index=True, axis = 0, sort = False)

# %% [markdown]
# ## Missing Values & Imputation

# %%
# Check for Columns with NA values
missing = df.isnull().sum()

# Vizualize missing value count
missing = missing[missing > 0]
missing.sort_values(inplace=True)
missing.plot.bar(figsize = (10,5))
plt.xlabel('Feature',fontsize=15)
plt.ylabel('Missing Count',fontsize = 15)
plt.title('Missing Values by Feature', fontsize=20)
# Out:
# Text(0.5, 1.0, 'Missing Values by Feature')

# %%
# Check Number of missing numerically
print(missing)
# Out:
# TotalBsmtSF        1
# GarageArea         1
# GarageCars         1
# KitchenQual        1
# Electrical         1
# BsmtUnfSF          1
# BsmtFinSF2         1
# BsmtFinSF1         1
# SaleType           1
# Exterior1st        1
# Exterior2nd        1
# Functional         2
# Utilities          2
# BsmtHalfBath       2
# BsmtFullBath       2
# MSZoning           4
# MasVnrArea        23
# MasVnrType        24
# BsmtFinType1      79
# BsmtFinType2      80
# BsmtQual          81
# BsmtCond          82
# BsmtExposure      82
# GarageType       157
# GarageCond       159
# GarageQual       159
# GarageYrBlt      159
# GarageFinish     159
# LotFrontage      486
# FireplaceQu     1420
# Fence           2348
# Alley           2721
# MiscFeature     2814
# PoolQC          2909
# dtype: int64

# %% [markdown]
# ### Impute using Mode

# %%
temp = ['Exterior1st','Exterior2nd','KitchenQual','SaleType','Functional','Electrical','BsmtHalfBath','BsmtFullBath','MSZoning','Utilities']

for col in temp:
    df[col]=df[col].fillna(df[col].mode()[0])

# %% [markdown]
# #### Impute Garage Features for observations that have a garage

# %%
# Calcs
fin_mode = df['GarageFinish'].mode()[0]
qual_mode = df['GarageQual'].mode()[0]
cond_mode = df['GarageCond'].mode()[0]

# Impute where Garage Exists

df['GarageCars']=df['GarageCars'].fillna(df['GarageCars'].mode()[0])

df['GarageArea']=df['GarageArea'].fillna(df['GarageArea'].mean())

df['GarageFinish']=np.where((df.GarageFinish.isna())&\
                          (df.GarageType.isna()==False),fin_mode,df['GarageFinish'])

df['GarageQual']=np.where((df.GarageQual.isna())&\
                          (df.GarageType.isna()==False),qual_mode,df['GarageQual'])

df['GarageCond']=np.where((df.GarageCond.isna())&\
                          (df.GarageType.isna()==False),cond_mode,df['GarageCond'])

df['GarageYrBlt']=np.where((df.GarageYrBlt.isna())&\
                          (df.GarageType.isna()==False),df['YearBuilt'],df['GarageYrBlt'])

# %% [markdown]
# #### Impute MasVnrType for observations that have MasVnr

# %%
vnr_mode = df['MasVnrType'].mode()[0]

df['MasVnrType']=np.where((df.MasVnrType.isna())&\
                          (df.MasVnrArea.isna()==False),vnr_mode,df['MasVnrType'])

# %% [markdown]
# #### Impute Basement Variables for houses with a Bsmt

# %%
qual_mode = df['BsmtQual'].mode()[0]

df['BsmtQual'] = np.where((df.BsmtQual.isna())&\
                          (df.BsmtFinType1.isna()==False),qual_mode,df['BsmtQual'])

# %%
cond_mode = df['BsmtCond'].mode()[0]

df['BsmtCond'] = np.where((df.BsmtCond.isna())&\
                          (df.BsmtFinType1.isna()==False),cond_mode,df['BsmtCond'])

# %%
#  Find mode of BsmtExposure
bsmt_exposure_mode = df['BsmtExposure'].mode()[0]

# Fill in for observation with basement
df['BsmtExposure']=np.where((df.BsmtExposure.isna())&(df.BsmtQual.isna()==False),bsmt_exposure_mode,df['BsmtExposure'])

# %%
#  Find mode of BsmtFinType2
bsmt2_exposure_mode = df['BsmtFinType2'].mode()[0]

# Fill in for observation with basement
df['BsmtFinType2']=np.where((df.BsmtFinType2.isna())&(df.BsmtQual.isna()==False),bsmt2_exposure_mode,df['BsmtFinType2'])

# %% [markdown]
# #### Impute Mode for LotFrontage by Neighborhood

# %%
# Impute Lot Frontage based on mean of neighborhood
df["LotFrontage"] = df.groupby("Neighborhood")["LotFrontage"].transform(lambda x: x.fillna(x.median()))

# %% [markdown]
# #### Impute PoolQC for houses with a Pool

# %%
#Find mode of PoolQC
pool_mode = df['PoolQC'].mode()[0]

# Fill in for observation with basement
df['PoolQC']=np.where((df.PoolQC.isna())&(df.PoolArea > 0),pool_mode,df['PoolQC'])

# %% [markdown]
# ### Impute none for variables in which NA means None

# %%
# Create List of Columns to impute None for missing
temp = ['PoolQC','BsmtQual','BsmtCond','BsmtExposure','BsmtFinType1','BsmtFinType2',"MasVnrType",'GarageType','GarageFinish','GarageQual','GarageCond','FireplaceQu','Fence','MiscFeature','Alley']

# Impute None
df[temp] = df[temp].fillna('None')

# %% [markdown]
# ### Impute 0 for MasVnrArea and GarageYrBlt

# %%
# Create List of Columns to impute 0 for missing
temp2 = ['MasVnrArea','GarageYrBlt','BsmtFinSF1','BsmtFinSF2','BsmtUnfSF','TotalBsmtSF']

# Impute 0
df[temp2] = df[temp2].fillna(0)

# %% [markdown]
# ### Get ride of Street

# %%
# Drop Utilities and Street as values are mostly all the same
df = df.drop(columns=['Street'])

# %% [markdown]
# ### Check Missingness

# %%
missing = df.isnull().sum()
missing = missing[missing > 0]
print('Missing Values:',missing.sum())
# Out:
# Missing Values: 0

# %% [markdown]
# ### Fix Garageyear 2207

# %%
df.loc[2592, 'GarageYrBlt'] = 2007

# %% [markdown]
# ## Feature Engineering

# %%
# Convert MSSubClass to String since it is really categorical
df['MSSubClass'] = df['MSSubClass'].apply(str)

# %% [markdown]
# ### Numerical Data

# %%
# Change Pool Area to Yes/No pool
df['PoolArea'] = df['PoolArea'].apply(lambda x: 1 if x > 0 else x)

# Rename Column
df=df.rename(columns = {'PoolArea':'Pool'})

# %%
# Create a total porch SF
df['PorchSF'] = df['OpenPorchSF']+df['EnclosedPorch']+\
df['3SsnPorch']+df['ScreenPorch']

# %%
# Turn PorchTypes to Binary
temp = ['OpenPorchSF','EnclosedPorch','3SsnPorch','ScreenPorch']

for col in temp:
    df[col] = df[col].apply(lambda x: 1 if x > 0 else x)

# %%
num_cols = df.columns[(df.dtypes == float) | (df.dtypes == int)].tolist()
num_cols

num = df[num_cols].copy()
num
# Out:
#       LotFrontage  LotArea  OverallQual  OverallCond  YearBuilt  YearRemodAdd  \
# 0            65.0     8450            7            5       2003          2003
# 1            80.0     9600            6            8       1976          1976
# 2            68.0    11250            7            5       2001          2002
# 3            60.0     9550            7            5       1915          1970
# 4            84.0    14260            8            5       2000          2000
# 5            85.0    14115            5            5       1993          1995
# 6            75.0    10084            8            5       2004          2005
# 7            80.0    10382            7            6       1973          1973
# 8            51.0     6120            7            5       1931          1950
# 9            50.0     7420            5            6       1939          1950
# 10           70.0    11200            5            5       1965          1965
# 11           85.0    11924            9            5       2005          2006
# 12           72.0    12968            5            6       1962          1962
# 13           91.0    10652            7            5       2006          2007
# 14           73.0    10920            6            5       1960          1960
# 15           51.0     6120            7            8       1929          2001
# 16           73.0    11241            6            7       1970          1970
# 17           72.0    10791            4            5       1967          1967
# 18           66.0    13695            5            5       2004          2004
# 19           70.0     7560            5            6       1958          1965
# 20          101.0    14215            8            5       2005          2006
# 21           57.0     7449            7            7       1930          1950
# 22           75.0     9742            8            5       2002          2002
# 23           44.0     4224            5            7       1976          1976
# 24           72.0     8246            5            8       1968          2001
# 25          110.0    14230            8            5       2007          2007
# 26           60.0     7200            5            7       1951          2000
# 27           98.0    11478            8            5       2007          2008
# 28           47.0    16321            5            6       1957          1997
# 29           60.0     6324            4            6       1927          1950
# ...           ...      ...          ...          ...        ...           ...
# 2889         50.0     7030            4            6       1925          1950
# 2890         75.0     9060            6            5       1957          1957
# 2891         69.0    12366            3            5       1945          1950
# 2892         50.0     9000            5            6       1951          1951
# 2893         60.0     8520            3            5       1916          1950
# 2894         41.0     5748            8            5       2005          2006
# 2895         44.0     3842            8            5       2004          2005
# 2896         69.0    23580            6            6       1979          1979
# 2897         65.0     8385            6            5       1978          1978
# 14                1          0            0     0        0       5    2008
# 15                0          0            0     0        0       7    2007
# 16                0          0            0     0      700       3    2010
# 17                0          0            0     0      500      10    2006
# 18                0          0            0     0        0       6    2008
# 19                0          0            0     0        0       5    2009
# 20                0          0            0     0        0      11    2006
# 21                1          0            0     0        0       6    2007
# 22                0          0            0     0        0       9    2008
# 23                0          0            0     0        0       6    2007
# 24                0          0            0     0        0       5    2010
# 25                0          0            0     0        0       7    2009
# 26                0          0            0     0        0       5    2010
# 27                0          0            0     0        0       5    2010
# 28                0          0            0     0        0      12    2006
# 29                1          0            0     0        0       5    2008
# ...             ...        ...          ...   ...      ...     ...     ...
# 2889              1          0            0     0        0       3    2006
# 2890              0          0            0     0        0       4    2006
# 2891              1          0            0     0        0      10    2006
# 2892              0          0            0     0        0      10    2006
# 2893              0          0            0     0        0       4    2006
# 2894              0          0            1     0        0       2    2006
# 2895              0          0            1     0        0      12    2006
# 2896              0          0            0     0        0       9    2006
# 2897              0          0            0     0        0      10    2006
# 2898              0          0            0     0        0       5    2006
# 2899              0          0            0     0        0       5    2006
# 2900              0          0            1     0        0       3    2006
# 2901              0          0            0     0        0      10    2006
# 2902              0          0            0     0        0      11    2006
# 2903              0          0            0     0        0       9    2006
# 2904              1          0            0     0        0       5    2006
# 2905              0          0            0     0        0      11    2006
# 2906              0          0            0     0        0       5    2006
# 2907              0          0            0     0        0      10    2006
# 2908              0          0            0     0        0       3    2006
# 2909              0          0            0     0        0       4    2006
# 2910              0          0            0     0        0       5    2006
# 2911              0          0            0     0        0       5    2006
# 2912              0          0            0     0        0      12    2006
# 2913              0          0            0     0        0       6    2006
# 2914              0          0            0     0        0       6    2006
# 2915              0          0            0     0        0       4    2006
# 2916              0          0            0     0        0       9    2006
# 2917              0          0            0     0      700       7    2006
# 2918              0          0            0     0        0      11    2006
#
#       SalePrice  PorchSF
# 0        208500       61
# 1        181500        0
# 2        223500       42
# 3        140000      307
# 4        250000       84
# 5        143000      350
# 6        307000       57
# 7        200000      432
# 8        129900      205
# 9        118000        4
# 10       129500        0
# 11       345000       21
# 12       144000      176
# 13       279500       33
# 14       157000      389
# 15       132000      112
# 16       149000        0
# 17        90000        0
# 18       159000      102
# 19       139000        0
# 20       325300      154
# 21       139400      205
# 22       230000      159
# 23       129900      110
# 24       154000       90
# 25       256300       56
# 26       134800       32
# 27       306000       50
# 28       207500      258
# 29        68500       87
# ...         ...      ...
# 2889          0       70
# 2890          0       21
# 2891          0       23
# 2892          0        0
# 2893          0        0
# 2894          0      206
# 2895          0      208
# 2896          0       28
# 2897          0        0
# 2898          0      100
# 2899          0        0
# 2900          0      138
# 2901          0      173
# 2902          0       38
# 2903          0      225
# 2904          0      135
# 2905          0       48
# 2906          0        0
# 2907          0      120
# 2908          0        0
# 2909          0        0
# 2910          0        0
# 2911          0        0
# 2912          0        0
# 2913          0       34
# 2914          0        0
# 2915          0       24
# 2916          0        0
# 2917          0       32
# 2918          0       48
#
# [2919 rows x 37 columns]

# %%
# Correlation Matrix - Numerically
corr = num.corr()
corr

# Correlation Matrix - Graphically
sns.set(style="white")

# Generate a mask for the upper triangle
mask = np.zeros_like(corr, dtype=np.bool)
mask[np.triu_indices_from(mask)] = True

# Set up the matplotlib figure
f, ax = plt.subplots(figsize=(11, 9))

# Generate a custom diverging colormap
cmap = sns.diverging_palette(20,220, as_cmap=True)

# Draw the heatmap with the mask and correct aspect ratio
sns.heatmap(corr, mask=mask, cmap=cmap, center=0,
            square=True, linewidths=.5, cbar_kws={"shrink": .5})

# %% [markdown]
# ### Aditional Features

# %%
# Create a total bath column
df['TotalBath'] = df['BsmtFullBath']+(0.5*df['BsmtHalfBath'])+\
df['FullBath']+(0.5*df['HalfBath'])

# %%
# Create a total Square Feet Column
df['TotalSF'] = df['GrLivArea']+df['TotalBsmtSF']

# %%
df['MultiFloor'] = df['2ndFlrSF'].apply(lambda x: 1 if x > 0 else 0)

# %% [markdown]
# ### Ordinal Encoding

# %%
ordinal = df[['FireplaceQu', 'BsmtQual', 'BsmtCond', 'GarageQual', 'GarageCond','ExterQual', 'ExterCond','HeatingQC',\
           'PoolQC', 'KitchenQual', 'BsmtFinType1','BsmtFinType2', 'GarageFinish', 'Functional',\
           'Fence','LandSlope','BsmtExposure','LotShape', 'PavedDrive','CentralAir']].copy()

# %%
# Create a dictionary of all ordinal values
temp = {}

for col in ordinal:
    temp[col] = ordinal[col].unique().tolist()

# %%
# Take a look at Values
temp
# Out:
# {'FireplaceQu': ['None', 'TA', 'Gd', 'Fa', 'Ex', 'Po'],
#  'BsmtQual': ['Gd', 'TA', 'Ex', 'None', 'Fa'],
#  'BsmtCond': ['TA', 'Gd', 'None', 'Fa', 'Po'],
#  'GarageQual': ['TA', 'Fa', 'Gd', 'None', 'Ex', 'Po'],
#  'GarageCond': ['TA', 'Fa', 'None', 'Gd', 'Po', 'Ex'],
#  'ExterQual': ['Gd', 'TA', 'Ex', 'Fa'],
#  'ExterCond': ['TA', 'Gd', 'Fa', 'Po', 'Ex'],
#  'HeatingQC': ['Ex', 'Gd', 'TA', 'Fa', 'Po'],
#  'PoolQC': ['None', 'Ex', 'Fa', 'Gd'],
#  'KitchenQual': ['Gd', 'TA', 'Ex', 'Fa'],
#  'BsmtFinType1': ['GLQ', 'ALQ', 'Unf', 'Rec', 'BLQ', 'None', 'LwQ'],
#  'BsmtFinType2': ['Unf', 'BLQ', 'None', 'ALQ', 'Rec', 'LwQ', 'GLQ'],
#  'GarageFinish': ['RFn', 'Unf', 'Fin', 'None'],
#  'Functional': ['Typ', 'Min1', 'Maj1', 'Min2', 'Mod', 'Maj2', 'Sev'],
#  'Fence': ['None', 'MnPrv', 'GdWo', 'GdPrv', 'MnWw'],
#  'LandSlope': ['Gtl', 'Mod', 'Sev'],
#  'BsmtExposure': ['No', 'Gd', 'Mn', 'Av', 'None'],
#  'LotShape': ['Reg', 'IR1', 'IR2', 'IR3'],
#  'PavedDrive': ['Y', 'N', 'P'],
#  'CentralAir': ['Y', 'N']}

# %%
# Create dict based on dict
temp_dict = {'None': 0, 'Po': 1, 'Fa': 2, 'TA': 3, 'Gd': 4, 'Ex': 5,'Mn': 2, 'Av': 3,'No': 1,\
             'Unf': 1, 'LwQ': 2, 'Rec': 3, 'BLQ': 4, 'ALQ': 5, 'GLQ': 6,'RFn': 4, 'Fin': 6,\
             'Sal': 0, 'Sev': 1, 'Maj2': 2, 'Maj1': 3, 'Mod': 4, 'Min2': 5, 'Min1': 6, 'Typ': 7,\
             'MnWw': 1, 'GdWo': 2, 'MnPrv': 3, 'GdPrv': 4,'Sev': 0, 'Mod': 1, 'Gtl': 2,'Y':1,'N':0,\
             'Reg':3, 'IR1':2, 'IR2':1, 'IR3':0}

# Convert Paved Drive on its own
ordinal['PavedDrive'] = ordinal['PavedDrive'].map({'Y': 2, 'P': 1, 'N': 0}).astype(int)

# Encode the rest of the columns
for col in ordinal.columns.drop("PavedDrive"):
    ordinal[col] = ordinal[col].map(temp_dict).astype(int)

# %%
# Replace columns in the train dataset
for col in ordinal.columns:
    df[col]=ordinal[col]

# %%
# Checkout remaining Categorical Columns
df.columns[df.dtypes == object]
# Out:
# Index(['MSSubClass', 'MSZoning', 'Alley', 'LandContour', 'Utilities',
#        'LotConfig', 'Neighborhood', 'Condition1', 'Condition2', 'BldgType',
#        'HouseStyle', 'RoofStyle', 'RoofMatl', 'Exterior1st', 'Exterior2nd',
#        'MasVnrType', 'Foundation', 'Heating', 'Electrical', 'GarageType',
#        'MiscFeature', 'SaleType', 'SaleCondition', 'section'],
#       dtype='object')

# %% [markdown]
# ### Dummify and Split Data for Modeling

# %%
# Code Breakdown to ordinal so that it is not dummified
df['section'] = df['section'].map({'Test': 0, 'Train': 1}).astype(int)

# %%
# Dummify
df = pd.get_dummies(df,drop_first=True)

# %% [markdown]
# ### Transformations

# %%
#skew(num)

# %%
#skewed_feats = df[num_cols].apply(lambda x: skew(x.dropna())).sort_values(ascending=False)
#skewness = pd.DataFrame({'Skew' :skewed_feats})
#skewness.head(10)

# %%
#skewness = skewness[abs(skewness.Skew)>0.75]

#from scipy.special import boxcox1p
#skewed_features = skewness.index
#lam = 0.15
#for feat in skewed_features:
    #df[feat] = boxcox1p(df[feat], lam)

# %%
# Split Data into Original Groups
train = df[df['section'] == 1].drop(columns=['section'])
test = df[df['section'] == 0].drop(columns=['section'])

# %% [markdown]
# ### Drop Outliers

# %%
train = train[train['GrLivArea'] < 4500]

# %%
# Remove Response Variable from X_tr
X_tr = train.drop(columns=['SalePrice'])
#X_tr.to_csv("X_tr.csv",index = False)

# Set Response Variable y_tr
y_tr = train['SalePrice']
#y_tr.to_csv("y_tr.csv",index = False)

# Remove Response Variable from X_tr
X_te = test.drop(columns=['SalePrice'])
#X_te.to_csv("X_te.csv",index = False)

# %% [markdown]
# ### Ridge Regression

# %%
from sklearn.linear_model import Ridge, Lasso, ElasticNet, LinearRegression
ridge = Ridge()
lasso = Lasso()
net   = ElasticNet()

# %%
from sklearn.preprocessing import RobustScaler
transformer = RobustScaler().fit(X_tr)
x_new = transformer.transform(X_tr)

# %%
from sklearn.model_selection import GridSearchCV

alphas = np.linspace(1e-3,200,20)
gs = GridSearchCV(ridge, {"alpha":alphas},cv=5,iid = True,scoring="neg_mean_squared_error")
gs.fit(X_tr, np.log(y_tr))
# Out:
# GridSearchCV(cv=5, error_score='raise-deprecating',
#        estimator=Ridge(alpha=1.0, copy_X=True, fit_intercept=True, max_iter=None,
#    normalize=False, random_state=None, solver='auto', tol=0.001),
#        fit_params=None, iid=True, n_jobs=None,
#        param_grid={'alpha': array([1.00000e-03, 1.05273e+01, 2.10535e+01, 3.15798e+01, 4.21061e+01,
#        5.26323e+01, 6.31586e+01, 7.36848e+01, 8.42111e+01, 9.47374e+01,
#        1.05264e+02, 1.15790e+02, 1.26316e+02, 1.36842e+02, 1.47369e+02,
#        1.57895e+02, 1.68421e+02, 1.78947e+02, 1.89474e+02, 2.00000e+02])},
#        pre_dispatch='2*n_jobs', refit=True, return_train_score='warn',
#        scoring='neg_mean_squared_error', verbose=0)

# %%
gs.best_params_
# Out:
# {'alpha': 21.053526315789476}

# %% [markdown]
# ### Lets run cross valdiation to calculate our test error

# %%
import sklearn.model_selection as ms
import sklearn
sklearn.metrics.SCORERS.keys()
# Out:
# dict_keys(['explained_variance', 'r2', 'neg_median_absolute_error', 'neg_mean_absolute_error', 'neg_mean_squared_error', 'neg_mean_squared_log_error', 'accuracy', 'roc_auc', 'balanced_accuracy', 'average_precision', 'neg_log_loss', 'brier_score_loss', 'adjusted_rand_score', 'homogeneity_score', 'completeness_score', 'v_measure_score', 'mutual_info_score', 'adjusted_mutual_info_score', 'normalized_mutual_info_score', 'fowlkes_mallows_score', 'precision', 'precision_macro', 'precision_micro', 'precision_samples', 'precision_weighted', 'recall', 'recall_macro', 'recall_micro', 'recall_samples', 'recall_weighted', 'f1', 'f1_macro', 'f1_micro', 'f1_samples', 'f1_weighted'])

# %%
ridge.set_params(alpha=21.053526315789476,normalize = False)
rmse = np.sqrt(-ms.cross_val_score(ridge,X=x_new, y=np.log(y_tr), scoring="neg_mean_squared_error", cv = 5))
rmse.mean()
# Out:
# 0.11463904830815552

# %% [markdown]
# ### Fit Model on Training Set

# %%
ridge.set_params(alpha=21.053526315789476)
ridge.fit(x_new, np.log(y_tr))
# Out:
# Ridge(alpha=21.053526315789476, copy_X=True, fit_intercept=True,
#    max_iter=None, normalize=False, random_state=None, solver='auto',
#    tol=0.001)

# %%
ridge.coef_
# Out:
# array([ 9.61625899e-03,  7.87932322e-03, -3.24249012e-03,  9.50401671e-03,
#         9.86620467e-02,  4.12617193e-02,  6.59894541e-02,  2.50905683e-02,
#         6.16363624e-03,  1.35310734e-02, -1.48190731e-02,  9.44103717e-03,
#        -5.76013645e-03,  1.21586953e-02,  1.43409870e-02,  2.94624107e-02,
#        -5.90315323e-03,  3.30601563e-05, -1.43597958e-02,  2.50195943e-02,
#         2.41940638e-02,  5.13741842e-02,  3.79397521e-02,  3.79454745e-02,
#        -3.42251324e-05,  7.24727723e-02, -2.19195783e-03, -1.25479911e-02,
#         4.72985689e-03,  2.07436851e-02, -3.12528734e-03, -2.90052902e-02,
#         1.87442163e-02,  1.29973362e-02,  2.39945656e-02,  1.55130223e-02,
#         1.79963200e-02, -1.45361664e-03,  3.59233297e-03,  2.54036259e-02,
#         1.58159717e-02,  2.06070768e-02,  1.05182271e-02,  1.32380972e-02,
#         1.49775568e-02, -3.50219197e-03, -3.97276863e-03,  1.80916451e-03,
#         1.42259593e-02,  2.34972674e-03,  1.07584322e-02, -2.65900770e-03,
#        -7.55189839e-07, -2.72228324e-03, -7.38111717e-03,  1.88463623e-02,
#         1.28800824e-02,  1.06287884e-04,  9.76549872e-03,  3.17460533e-04,
#        -4.59477232e-04, -7.48499346e-03,  8.29215720e-03,  8.90777857e-03,
#         1.26119496e-02, -9.79201884e-03, -3.81499808e-04,  4.59623211e-02,
#         8.01596532e-03, -1.64391888e-02,  1.28585887e-02,  6.00690307e-03,
#        -1.84691475e-03,  5.95707013e-02,  3.87768688e-02])

# %% [markdown]
# ### Make a Prediction

# %%
x_new1 = transformer.transform(X_te)
predict_ridge = ridge.predict(x_new1)

# %%
predict_ridge
# Out:
# array([11.64223996, 11.95567544, 12.08168448, ..., 12.05466901,
#        11.63765948, 12.31090875])

# %%
# submit_kaggle('ridge_reg_3.csv',predict_ridge)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-60-96b35c3553c8> in <module>
# ----> 1 submit_kaggle('ridge_reg_3.csv',predict_ridge)
#
# NameError: name 'submit_kaggle' is not defined

# %% [markdown]
# ### Lasso

# %%
alphas = np.linspace(1e-3,200,20)
gs = GridSearchCV(lasso, {"alpha":alphas},cv=5,iid = True,scoring="neg_mean_squared_error")
gs.fit(x_new, np.log(y_tr))
# Out:
# GridSearchCV(cv=5, error_score='raise-deprecating',
#        estimator=Lasso(alpha=1.0, copy_X=True, fit_intercept=True, max_iter=1000,
#    normalize=False, positive=False, precompute=False, random_state=None,
#    selection='cyclic', tol=0.0001, warm_start=False),
#        fit_params=None, iid=True, n_jobs=None,
#        param_grid={'alpha': array([1.00000e-03, 1.05273e+01, 2.10535e+01, 3.15798e+01, 4.21061e+01,
#        5.26323e+01, 6.31586e+01, 7.36848e+01, 8.42111e+01, 9.47374e+01,
#        1.05264e+02, 1.15790e+02, 1.26316e+02, 1.36842e+02, 1.47369e+02,
#        1.57895e+02, 1.68421e+02, 1.78947e+02, 1.89474e+02, 2.00000e+02])},
#        pre_dispatch='2*n_jobs', refit=True, return_train_score='warn',
#        scoring='neg_mean_squared_error', verbose=0)

# %%
gs.best_params_
# Out:
# {'alpha': 0.001}

# %%
lasso.set_params(alpha=0.001)
rmse = np.sqrt(-ms.cross_val_score(lasso,X=x_new, y=np.log(y_tr), scoring="neg_mean_squared_error", cv = 5))
rmse.mean()
# Out:
# 0.114303468870482

# %%
lasso.fit(x_new, np.log(y_tr))
# Out:
# Lasso(alpha=0.001, copy_X=True, fit_intercept=True, max_iter=1000,
#    normalize=False, positive=False, precompute=False, random_state=None,
#    selection='cyclic', tol=0.0001, warm_start=False)

# %%
lasso.coef_
# Out:
# array([ 1.03702088e-02,  7.66945445e-03, -3.84382281e-03,  0.00000000e+00,
#         1.16810612e-01,  4.11791932e-02,  7.69396599e-02,  2.14722259e-02,
#         4.95133628e-03,  1.18121457e-02, -6.22816680e-03,  2.44903833e-03,
#        -0.00000000e+00,  1.15397923e-02,  0.00000000e+00,  5.38399661e-02,
#        -3.76625884e-03,  5.24206303e-05, -0.00000000e+00,  0.00000000e+00,
#         2.37591048e-02,  4.28859561e-02,  6.69613933e-03,  0.00000000e+00,
#        -7.13437884e-05,  1.03290623e-01,  0.00000000e+00, -0.00000000e+00,
#        -0.00000000e+00,  9.52424476e-03, -0.00000000e+00, -2.19116277e-02,
#         1.96171269e-02,  3.47427019e-03,  2.25847315e-02,  1.50700926e-02,
#         1.64155642e-02,  2.54686888e-04,  1.83433881e-03,  2.57176826e-02,
#         1.44154124e-02,  1.19492036e-02,  7.89570419e-04,  7.36163662e-03,
#         1.35215084e-02, -0.00000000e+00, -0.00000000e+00,  0.00000000e+00,
#         5.14883560e-03,  0.00000000e+00,  0.00000000e+00, -2.63958977e-03,
#        -2.54463863e-06, -1.05580555e-03, -3.90143193e-03,  1.77123014e-02,
#         1.11846330e-02,  8.84083049e-02, -0.00000000e+00,  0.00000000e+00,
#        -5.09386123e-02, -0.00000000e+00, -0.00000000e+00,  1.04678784e-02,
#        -2.03180949e-02,  0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#        -0.00000000e+00,  1.87924123e-03, -0.00000000e+00,  0.00000000e+00,
#         0.00000000e+00, -0.00000000e+00,  4.28007489e-02,  0.00000000e+00,
#         5.74032517e-02, -0.00000000e+00, -0.00000000e+00,  0.00000000e+00,
#         0.00000000e+00, -0.00000000e+00, -0.00000000e+00, -0.00000000e+00,
#         2.60785132e-02, -0.00000000e+00, -0.00000000e+00, -0.00000000e+00,
#         0.00000000e+00, -0.00000000e+00,  3.89104720e-02,  0.00000000e+00,
#        -0.00000000e+00,  8.91607151e-02, -0.00000000e+00, -0.00000000e+00,
#        -7.58556919e-03, -7.77455492e-04, -0.00000000e+00,  0.00000000e+00,
#         0.00000000e+00, -0.00000000e+00,  0.00000000e+00,  2.57877783e-02,
#        -0.00000000e+00,  0.00000000e+00,  0.00000000e+00, -0.00000000e+00,
#         3.12359249e-02,  3.27285358e-02, -0.00000000e+00,  0.00000000e+00,
#         0.00000000e+00,  4.01610806e-02, -0.00000000e+00,  0.00000000e+00,
#        -0.00000000e+00,  0.00000000e+00, -0.00000000e+00,  0.00000000e+00,
#         0.00000000e+00,  0.00000000e+00,  0.00000000e+00, -0.00000000e+00,
#        -0.00000000e+00, -0.00000000e+00,  0.00000000e+00, -0.00000000e+00,
#        -0.00000000e+00, -2.95090066e-03, -0.00000000e+00,  0.00000000e+00,
#         0.00000000e+00, -0.00000000e+00, -0.00000000e+00, -0.00000000e+00,
#        -0.00000000e+00,  0.00000000e+00, -0.00000000e+00, -0.00000000e+00,
#         0.00000000e+00,  0.00000000e+00,  0.00000000e+00, -0.00000000e+00,
#         0.00000000e+00,  0.00000000e+00, -0.00000000e+00, -0.00000000e+00,
#        -0.00000000e+00,  0.00000000e+00, -0.00000000e+00, -0.00000000e+00,
#         3.57446979e-02, -0.00000000e+00, -0.00000000e+00, -5.43569155e-03,
#         0.00000000e+00,  8.92871245e-03, -0.00000000e+00, -0.00000000e+00,
#         0.00000000e+00,  0.00000000e+00, -7.12862059e-03,  0.00000000e+00,
#         0.00000000e+00, -0.00000000e+00, -0.00000000e+00, -0.00000000e+00,
#        -0.00000000e+00, -0.00000000e+00, -0.00000000e+00,  0.00000000e+00,
#        -0.00000000e+00, -0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#         0.00000000e+00,  0.00000000e+00, -0.00000000e+00, -4.80065679e-03,
#         0.00000000e+00,  1.13681297e-02, -0.00000000e+00,  3.08421906e-02,
#         0.00000000e+00,  0.00000000e+00, -0.00000000e+00, -0.00000000e+00,
#         0.00000000e+00, -0.00000000e+00, -0.00000000e+00,  0.00000000e+00,
#         0.00000000e+00, -0.00000000e+00, -0.00000000e+00, -0.00000000e+00,
#         0.00000000e+00, -0.00000000e+00,  0.00000000e+00, -0.00000000e+00,
#         0.00000000e+00, -0.00000000e+00,  0.00000000e+00, -0.00000000e+00,
#        -0.00000000e+00, -0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#         0.00000000e+00, -0.00000000e+00,  0.00000000e+00,  1.01923744e-01,
#         0.00000000e+00, -0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#        -0.00000000e+00,  5.31107069e-02,  0.00000000e+00])

# %%
temp = pd.DataFrame({
    "Feature": X_tr.columns,
    "Coef": lasso.coef_
})

temp[temp.Coef != 0].sort_values(by = "Coef", ascending = False)
# Out:
#                   Feature      Coef
# 4             OverallQual  0.116811
# 25              GrLivArea  0.103291
# 211          SaleType_New  0.101924
# 93   Neighborhood_Crawfor  0.089161
# 57                TotalSF  0.088408
# 6               YearBuilt  0.076940
# 76            MSZoning_RL  0.057403
# 15             BsmtFinSF1  0.053840
# 217  SaleCondition_Normal  0.053111
# 21             CentralAir  0.042886
# 74            MSZoning_FV  0.042801
# 5             OverallCond  0.041179
# 113       Condition1_Norm  0.040161
# 90   Neighborhood_BrkSide  0.038910
# 152   Exterior1st_BrkFace  0.035745
# 109  Neighborhood_StoneBr  0.032729
# 108  Neighborhood_Somerst  0.031236
# 183      Foundation_PConc  0.030842
# 84      LotConfig_CulDSac  0.026079
# 103  Neighborhood_NridgHt  0.025788
# 39             GarageCars  0.025718
# 20              HeatingQC  0.023759
# 34             Functional  0.022585
# 7            YearRemodAdd  0.021472
# 32            KitchenQual  0.019617
# 55                PorchSF  0.017712
# 36            FireplaceQu  0.016416
# 35             Fireplaces  0.015070
# 40             GarageArea  0.014415
# 44             WoodDeckSF  0.013522
# ..                    ...       ...
# 157   Exterior1st_MetalSd  0.008929
# 1                 LotArea  0.007669
# 43             PavedDrive  0.007362
# 22               1stFlrSF  0.006696
# 48            ScreenPorch  0.005149
# 8              MasVnrArea  0.004951
# 33           TotRmsAbvGrd  0.003474
# 11               BsmtQual  0.002449
# 69          MSSubClass_70  0.001879
# 38           GarageFinish  0.001834
# 42             GarageCond  0.000790
# 37            GarageYrBlt  0.000255
# 17             BsmtFinSF2  0.000052
# 52                MiscVal -0.000003
# 24           LowQualFinSF -0.000071
# 97   Neighborhood_MeadowV -0.000777
# 53                 MoSold -0.001056
# 51                  Fence -0.002640
# 129        BldgType_Twnhs -0.002951
# 16           BsmtFinType2 -0.003766
# 2                LotShape -0.003844
# 54                 YrSold -0.003901
# 179    MasVnrType_BrkFace -0.004801
# 155   Exterior1st_HdBoard -0.005436
# 10              ExterCond -0.006228
# 162   Exterior1st_Wd Sdng -0.007129
# 96    Neighborhood_IDOTRR -0.007586
# 64          MSSubClass_30 -0.020318
# 31           KitchenAbvGr -0.021912
# 60         MSSubClass_160 -0.050939
#
# [68 rows x 2 columns]

# %%
predict_lasso = lasso.predict(x_new1)

# %%
# submit_kaggle('lasso_reg.csv',predict)

# %% [markdown]
# ### ElasticNet

# %%
### ElasticNet
alphaSize  = 40
rhoSize    = 30
alphaRange = np.linspace(1e-2, 10, alphaSize)
rhoRange   = np.linspace(0.01, 1, rhoSize)

parametersGrid = {"alpha": alphaRange,
                  "l1_ratio": rhoRange}

grid = GridSearchCV(net, parametersGrid, cv=5)
grid.fit(x_new, np.log(y_tr))
# Out:
# GridSearchCV(cv=5, error_score='raise-deprecating',
#        estimator=ElasticNet(alpha=1.0, copy_X=True, fit_intercept=True, l1_ratio=0.5,
#       max_iter=1000, normalize=False, positive=False, precompute=False,
#       random_state=None, selection='cyclic', tol=0.0001, warm_start=False),
#        fit_params=None, iid='warn', n_jobs=None,
#        param_grid={'alpha': array([ 0.01   ,  0.26615,  0.52231,  0.77846,  1.03462,  1.29077,
#         1.54692,  1.80308,  2.05923,  2.31538,  2.57154,  2.82769,
#         3.08385,  3.34   ,  3.59615,  3.85231,  4.10846,  4.36462,
#         4.62077,  4.87692,  5.13308,  5.38923,  5.64538,  5.90154,
#         6.1...76,
#        0.7269 , 0.76103, 0.79517, 0.82931, 0.86345, 0.89759, 0.93172,
#        0.96586, 1.     ])},
#        pre_dispatch='2*n_jobs', refit=True, return_train_score='warn',
#        scoring=None, verbose=0)

# %%
grid.best_params_
# Out:
# {'alpha': 0.01, 'l1_ratio': 0.04413793103448276}

# %%
net.set_params(alpha=0.01, l1_ratio=0.04413793103448276)
rmse = np.sqrt(-ms.cross_val_score(net,X=x_new, y=np.log(y_tr), scoring="neg_mean_squared_error", cv = 5))
rmse.mean()
# Out:
# 0.11376794893454442

# %%
net.fit(x_new, np.log(y_tr))
# Out:
# ElasticNet(alpha=0.01, copy_X=True, fit_intercept=True,
#       l1_ratio=0.04413793103448276, max_iter=1000, normalize=False,
#       positive=False, precompute=False, random_state=None,
#       selection='cyclic', tol=0.0001, warm_start=False)

# %%
predict_net = net.predict(x_new1)

# %%
# submit_kaggle('net_reg.csv',predict)

# %% [markdown]
# ### Gradient Boosting

# %%
from sklearn.ensemble import GradientBoostingClassifier, GradientBoostingRegressor

# %%
gbm = GradientBoostingRegressor()

# %%
gbm.fit(x_new, np.log(y_tr))
# Out:
# GradientBoostingRegressor(alpha=0.9, criterion='friedman_mse', init=None,
#              learning_rate=0.1, loss='ls', max_depth=3, max_features=None,
#              max_leaf_nodes=None, min_impurity_decrease=0.0,
#              min_impurity_split=None, min_samples_leaf=1,
#              min_samples_split=2, min_weight_fraction_leaf=0.0,
#              n_estimators=100, n_iter_no_change=None, presort='auto',
#              random_state=None, subsample=1.0, tol=0.0001,
#              validation_fraction=0.1, verbose=0, warm_start=False)

# %%
gbm.score(x_new, np.log(y_tr))
# Out:
# 0.959692116135507

# %%
predict_gbm = gbm.predict(x_new1)

# %%
# submit_kaggle('gbm_test.csv',predict)

# %%
gbm.feature_importances_
# Out:
# array([4.67097321e-04, 1.38486764e-02, 1.42319138e-05, 0.00000000e+00,
#        3.66704745e-01, 1.56565552e-02, 1.13305035e-02, 1.52244687e-02,
#        1.11382351e-04, 1.37764823e-02, 9.44662150e-04, 4.93717413e-03,
#        0.00000000e+00, 2.19790022e-03, 2.09667227e-03, 5.34798957e-03,
#        1.46721726e-05, 6.94594231e-05, 1.44462954e-03, 2.66067972e-04,
#        1.45180747e-03, 1.40901863e-02, 6.72778398e-03, 2.35940027e-03,
#        1.10903092e-04, 1.18954363e-02, 9.73465987e-05, 2.50553055e-05,
#        7.05835876e-05, 0.00000000e+00, 2.81173369e-04, 0.00000000e+00,
#        1.93888804e-02, 1.14881408e-04, 1.90572405e-03, 2.84212806e-04,
#        1.55129376e-02, 4.87776556e-03, 1.38881504e-02, 1.53951042e-02,
#        4.91959914e-03, 0.00000000e+00, 5.47717481e-03, 1.25925195e-03,
#        1.30356788e-03, 2.34991343e-05, 3.20200573e-05, 0.00000000e+00,
#        5.40061979e-04, 0.00000000e+00, 3.72840257e-04, 0.00000000e+00,
#        1.92951645e-05, 6.26697269e-04, 1.16757548e-03, 2.82968083e-03,
#        5.16830319e-02, 3.41109837e-01, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        9.57439195e-04, 0.00000000e+00, 0.00000000e+00, 4.54498125e-04,
#        0.00000000e+00, 5.28145980e-05, 5.92322198e-05, 9.07086941e-05,
#        0.00000000e+00, 0.00000000e+00, 1.82829755e-04, 4.26262770e-05,
#        5.81926131e-03, 3.02836354e-03, 1.11718387e-04, 9.88188966e-05,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        4.62939266e-04, 5.35712687e-05, 0.00000000e+00, 1.49104112e-04,
#        0.00000000e+00, 0.00000000e+00, 3.32147703e-04, 3.51124891e-04,
#        0.00000000e+00, 3.22549888e-03, 2.93385377e-05, 0.00000000e+00,
#        6.19072236e-04, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 5.91299951e-05, 0.00000000e+00, 0.00000000e+00,
#        2.75032765e-04, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 2.99212143e-04, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 3.48309632e-04, 2.24179390e-04, 0.00000000e+00,
#        2.39768463e-04, 2.46099049e-05, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 1.04571741e-05,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 2.16321675e-05,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 4.79708785e-04,
#        1.07991874e-03, 0.00000000e+00, 0.00000000e+00, 8.85078327e-05,
#        0.00000000e+00, 4.45683035e-05, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 1.52923395e-04, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 5.96253351e-05,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        4.20671670e-05, 0.00000000e+00, 0.00000000e+00, 2.13746489e-05,
#        2.62703627e-05, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 1.27974552e-04,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        2.11870384e-03, 0.00000000e+00, 2.45339067e-05, 8.60258720e-05,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 1.00155589e-03,
#        0.00000000e+00, 2.36998320e-04, 0.00000000e+00, 1.22546625e-04,
#        7.22733582e-04, 1.64568717e-03, 0.00000000e+00])

# %%
predict_lasso
# Out:
# array([11.61064492, 11.94223241, 12.07285953, ..., 12.05644666,
#        11.65205255, 12.34692672])

# %%
predict_avg = ((0.5*predict_ridge) + (0.5*predict_net))

# %%
predict_avg
# Out:
# array([11.63280006, 11.94711948, 12.07944612, ..., 12.05767335,
#        11.6452796 , 12.320174  ])

# %%
submit_kaggle("predict_avg_4.csv",predict_avg)
# Out:
# File Saved!

# %% [markdown]
# ## Submit

# %%
# Input filename as a .csv

def submit_kaggle(filename, prediction):
    vals = np.exp(prediction)
    indexes = list(range(1461,1461+len(vals)))
    predictions = pd.DataFrame()
    predictions['Id'] = indexes
    predictions['SalePrice'] = vals
    predictions.to_csv(filename,index = False)
    print('File Saved!')
